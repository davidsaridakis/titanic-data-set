# %%
# Data Handling
import numpy as np
import pandas as pd

# Visualization
import matplotlib as plt
import seaborn as sns

# %%
# Load CSV files
train_path = "data/raw/train.csv"
test_path = "data/raw/test.csv"

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# Check files
print("Train shape: ", train.shape)
print("Test shape: ", test.shape)
train.head()

# Check for missing values in the data
train.isnull().sum()

# Summary stats
train.describe()

# Survival rate by sex
sns.barplot(x='Sex', y='Survived', data=train)
plt.show()
# Out:
# Train shape:  (891, 12)
# Test shape:  (418, 11)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 21
#      19 # Survival rate by sex
#      20 sns.barplot(x='Sex', y='Survived', data=train)
# ---> 21 plt.show()
#
# File /mnt/c/Users/guada/Desktop/Python/kaggle/titanic-data-set/venv/lib/python3.12/site-packages/matplotlib/_api/__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'
