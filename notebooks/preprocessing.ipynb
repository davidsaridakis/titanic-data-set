# %%
import sys
from pathlib import Path
# Check one level up for imports
sys.path.append(str(Path.cwd().parent))

import pandas as pd
import numpy as np
from src.preprocessing import clean_data

# %%
# --- Test preprocessing.py script ---
train = pd.read_csv("../data/raw/train.csv")
X, y = clean_data(train, is_train=True)


# Sanity check
X.shape
y.shape
X.isnull().sum()
X.dtypes
# Out:
# (891, 10)
# PassengerId      int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Family Size      int64
# Embarked_Q        bool
# Embarked_S        bool
# dtype: object
